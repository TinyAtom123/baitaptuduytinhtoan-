# %%
name = input("Ten chu ho:" )                                                #bai 8
so_dien = int(input("Chi so thang truoc: "))
dien = int(input("Chi so thang nay: "))
print(name)
print(so_dien)
print(dien)
if dien < 50:
    tien = dien * 1984
    print("So tien phai tra:", tien)
elif 51 < dien < 100:
    tien = 50 * 1984 + (dien - 50) * 2050
    print("So tien phai tra:", tien)
elif 101 < dien < 200:
    tien = 50 * 1984 + 50 * 2050 + (dien - 100) * 2380
    print("So tien phai tra:", tien)
elif 201 < dien < 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (dien - 200) * 2998
    print("So tien phai tra:", tien)
elif 301 < dien < 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (dien - 300) * 3350
    print("So tien phai tra:", tien)
elif 401 < dien:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (dien - 400) * 3460
    print("So tien phai tra:", tien)
# Out:
# Long
# 2012
# 2026
# So tien phai tra: 6700460

# %%
word = input("Nhap vao mot tu (tren 20 chu cai): ")                             #bai 7
print(word)
if len(word) < 20:
    print("Tu ban nhap vao khong du 20 chu cai.")
else:
    for i in range(len(word)):
        if i == 4:
            print(word[i])
        elif i == 8:
            print(word[i])
# Out:
# kookaburathegoodchef
# a
# a

# %%
n = int(input())                                                    #bai 1
n = 2 * n
print(n)
# Out:
# 2

# %%
a = float(input())                                                  #bai 2
b = float(input())
area = a * b - a * 3.14
area = round(area, 2)
print(area)
# Out:
# 3.26

# %%
n = input()                                                             #bai 3
if n == n.upper():
    print(n.lower())
else:
    print(n.upper())
# Out:
# c

# %%
n = str(input())  
if n.isalpha():
    print(n, "la mot ki tu alphabet") 
else:
    print(n, "khong phai ki tu alphabet")                                 #bai 4
# Out:
# f la mot ki tu alphabet

# %%
import math

                                                                         
a = float(input("Canh goc vuong 1: "))                                    # bai 6
b = float(input("Canh goc vuong 2: "))
c = float(input("Canh huyen: "))
print(a,  b,  c)
if c ** 2 == (a ** 2 + b ** 2):
    print("La 3 canh cua mot tam giac vuong")
    area = (a * b )/ 2
    print("Dien tich tam giac vuong la:", area)
else:
    print("Khong phai la 3 canh cua mot tam giac vuong")
# Out:
# 3.0 4.0 5.0
# La 3 canh cua mot tam giac vuong
# Dien tich tam giac vuong la: 6.0

# %%
n = input("Nhap chu in hoa:")                                                               #bai 5
print(n)
if n.islower():
    print("Khong phai chu in hoa")
elif ord(n) + 31 < 97:
    print("Khong co chu cai truoc A")
else:
    print(chr(ord(n) + 31))
# Out:
# G
# f
